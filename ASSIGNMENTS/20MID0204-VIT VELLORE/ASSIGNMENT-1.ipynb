# %%
import numpy as np
import pandas as pd
#generatung random values
d = np.random.rand(4, 4)
# Creating a DataFrame
df = pd.DataFrame(d, columns=['Feature 1', 'Feature 2', 'Feature 3', 'Feature 4'],
index = ['Ob1','Ob2','Ob3','Ob4'])
# Print the DataFrame
print(df)
# Out:
#      Feature 1  Feature 2  Feature 3  Feature 4
# Ob1   0.775320   0.436696   0.619399   0.518913
# Ob2   0.842588   0.878866   0.141754   0.130321
# Ob3   0.176702   0.341025   0.775908   0.511290
# Ob4   0.812809   0.520577   0.871880   0.162066

# %%
import numpy as np
import pandas as pd
#Renaming Columns
df = df.rename(columns = {'Feature 1' : 'Random Value 1',
'Feature 2' : 'Random Value 2',
'Feature 3' : 'Random Value 3',
'Feature 4' : 'Random Value 4'})
# Print the DataFrame
print(df)
# Out:
#      Random Value 1  Random Value 2  Random Value 3  Random Value 4
# Ob1        0.775320        0.436696        0.619399        0.518913
# Ob2        0.842588        0.878866        0.141754        0.130321
# Ob3        0.176702        0.341025        0.775908        0.511290
# Ob4        0.812809        0.520577        0.871880        0.162066

# %%
import numpy as np
import pandas as pd
#Statistical Description
stat = df.describe()
# Print the DataFrame
print(df)
print('\n')
print(stat)
# Out:
#      Random Value 1  Random Value 2  Random Value 3  Random Value 4
# Ob1        0.775320        0.436696        0.619399        0.518913
# Ob2        0.842588        0.878866        0.141754        0.130321
# Ob3        0.176702        0.341025        0.775908        0.511290
# Ob4        0.812809        0.520577        0.871880        0.162066
#
#
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.651855        0.544291        0.602235        0.330648
# std          0.317962        0.234803        0.324144        0.213406
# min          0.176702        0.341025        0.141754        0.130321
# 25%          0.625665        0.412778        0.499988        0.154130
# 50%          0.794064        0.478637        0.697654        0.336678
# 75%          0.820254        0.610150        0.799901        0.513196
# max          0.842588        0.878866        0.871880        0.518913

# %%
import numpy as np
import pandas as pd
#Checking NULL values
null_val = df.isnull().sum()
#Checking Data types
data_type = df.dtypes
# Print the DataFrame
print(null_val)
print('\n')
print(data_type)
# Out:
# Random Value 1    0
# Random Value 2    0
# Random Value 3    0
# Random Value 4    0
# dtype: int64
#
#
# Random Value 1    float64
# Random Value 2    float64
# Random Value 3    float64
# Random Value 4    float64
# dtype: object

# %%
import numpy as np
import pandas as pd
# Display columns using the location method
location_method = df[['Random Value 2', 'Random Value 3']]
print("Columns using location method:")
print(location_method)
# Display columns using the index location method
index_location_method = df.iloc[:, 1:3]
print("\nColumns using index location method :")
print(index_location_method)
# Out:
# Columns using location method:
#      Random Value 2  Random Value 3
# Ob1        0.436696        0.619399
# Ob2        0.878866        0.141754
# Ob3        0.341025        0.775908
# Ob4        0.520577        0.871880
#
# Columns using index location method :
#      Random Value 2  Random Value 3
# Ob1        0.436696        0.619399
# Ob2        0.878866        0.141754
# Ob3        0.341025        0.775908
# Ob4        0.520577        0.871880
